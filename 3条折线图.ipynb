# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('E:/Desktop/wxy/结果/data.csv',header = None)

# %%
filenames_out = ('E:/Desktop/wxy/结果/2模仿/2方差最小',
                 'E:/Desktop/wxy/结果/3历史',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.25',
                 'E:/Desktop/wxy/结果/2模仿/2方差最小',
                 'E:/Desktop/wxy/结果/3历史',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.5',
                 'E:/Desktop/wxy/结果/2模仿/2方差最小',
                 'E:/Desktop/wxy/结果/3历史',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.75',
                )

# %%
i = 1
for m in [2,8]:
    for j in range( len(filenames_out)):
        allDir = 'b = ' + str(m)
        fname2 = 'P_c.csv'
        dataa = pd.read_csv(os.path.join(filenames_out[j], allDir,fname2))
        data[i] = dataa['0']
        i = i + 1

# %%
#linecolor = ('#C83828','#1B5E20','#8C63C4')
linecolor = ('#1B5E20','#4d5aaf','#C83828')
plt.figure(figsize=(3,1.4),dpi=600)
plt.subplots_adjust(hspace=0.3, wspace=0.1)
font_size = 5
line_width = 0.6

plt.subplot(2,3,1)
#plt.title( chr(956)+' = 0.25',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
#plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[1], color=linecolor[0],linewidth = line_width)
#plt.plot(data[0],data[2], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[3], color=linecolor[2],linewidth = line_width)
#plt.text(-27,0.5,' b = 1.2 ',fontname = 'Times New Roman',size = 20)
#loc = 'upper left'
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(32,0.72  ,' b = 1.2 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,2)
#plt.title(chr(956)+' = 0.50',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[4], color=linecolor[0],linewidth = line_width)
#plt.plot(data[0],data[5], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[6], color=linecolor[2],linewidth = line_width)
plt.text(32,0.72  ,' b = 1.2 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )



plt.subplot(2,3,3)
#plt.title(chr(956)+' = 0.75',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[7], color=linecolor[0],linewidth = line_width)
#plt.plot(data[0],data[8], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[9], color=linecolor[2],linewidth = line_width)
plt.text(32,0.72 ,' b = 1.2 \n'+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )


plt.subplot(2,3,4)
#plt.title('b = 1.6',fontname = 'Times New Roman',fontsize = 15)  ###子图的题目，字体，大小
#plt.xticks(())  ##不要x轴的刻度线
#plt.yticks(())   ##不要y轴的刻度线
plt.ylim(-0.1,1.1)   ###y轴的最小最大值
plt.plot(data[0],data[10], color=linecolor[0],linewidth = line_width)  ##第一条折线图
#plt.plot(data[0],data[11], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[12], color=linecolor[2],linewidth = line_width)
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})   ###y轴的标签 $_c$表示c是下标
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})  ###x轴的标签
#plt.text(-27,0.5,' b = 1.8 ',fontname = 'Times New Roman',size = 20)
plt.text(32,0.72 ,' b = 1.8 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )

plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,5)
#plt.title('b = 1.8',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[13], color=linecolor[0],label = 'Updating rule (i)',linewidth = line_width)
#plt.plot(data[0],data[14], color=linecolor[1],label = 'Updating rule (ii)',linewidth = line_width)
plt.plot(data[0],data[15], color=linecolor[2],label = 'Updating rule (ii)',linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(32,0.72  ,' b = 1.8 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.legend(ncol=3, bbox_to_anchor = (1.6,1.35),
           prop = {'family' : 'Times New Roman','size': font_size},
          frameon = False) # 显示图例
#loc = 'upper left'


plt.subplot(2,3,6)
#plt.title('b = 2.0',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[16], color=linecolor[0],linewidth = line_width)
#plt.plot(data[0],data[17], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[18], color=linecolor[2],linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(32,0.72 ,' b = 1.8 \n'+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)
         
         
         
plt.savefig('E:/Desktop/7.29/figure9.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure10.svg',bbox_inches='tight',pad_inches=0.0)

# %%
#linecolor = ('#C83828','#1B5E20','#8C63C4')
linecolor = ('#1B5E20','#4d5aaf','#C83828')
plt.figure(figsize=(3,1),dpi=600)
plt.subplots_adjust(hspace=0.3, wspace=0.5)
font_size = 5
line_width = 0.6


plt.subplot(1,2,1)
#plt.title(chr(956)+' = 0.50',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[4], color=linecolor[0],linewidth = line_width,label = 'Updating rule (i)')
#plt.plot(data[0],data[5], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[6], color=linecolor[2],linewidth = line_width,label = 'Updating rule (ii)')
plt.title('(a) b = 1.2 \n',y=-0.7,
         fontdict = {'family' : 'Times New Roman','size': font_size,},
         )
#plt.title(chr(956)+' = 0.50',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)
plt.legend(ncol=1, 
           prop = {'family' : 'Times New Roman','size': font_size},
          frameon = False) # 显示图例
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})

plt.subplot(1,2,2)
#plt.title('b = 1.8',fontname = 'Times New Roman',fontsize = 15)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[13], color=linecolor[0],label = 'Updating rule (i)',linewidth = line_width)
#plt.plot(data[0],data[14], color=linecolor[1],label = 'Updating rule (ii)',linewidth = line_width)
plt.plot(data[0],data[15], color=linecolor[2],label = 'Updating rule (ii)',linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})

plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.legend(ncol=1, 
           prop = {'family' : 'Times New Roman','size': font_size},
          frameon = False) # 显示图例
#loc = 'upper left'
plt.title('(b) b = 1.8 \n',y=-0.7,
         fontdict = {'family' : 'Times New Roman','size': font_size,},
         )
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})

plt.savefig('E:/Desktop/7.29/figure5.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure5_改.svg',bbox_inches='tight',pad_inches=0.0)
