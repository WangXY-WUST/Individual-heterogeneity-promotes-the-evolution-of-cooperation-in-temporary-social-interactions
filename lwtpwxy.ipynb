# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
lj = pd.read_csv('E:/Desktop/N_lj.csv',header = 0)
plt.plot(lj['a'], lj['a1'], color='blue',linewidth = 1)
plt.xlabel('times')
plt.ylabel('the number of players')
plt.savefig('E:/Desktop/博弈人数.jpg')

# %%
#fg = pd.read_csv('E:/Desktop/10min.csv')
fg = pd.read_csv('E:/Desktop/时间间隔/20min.csv')
#fg = pd.read_csv('E:/Desktop/10mingh.csv')

# %%
plt.figure(figsize=(12,6))
#plt.subplots(4,3,sharex='col',sharey='row')
plt.subplots_adjust(hspace=0.3, wspace=0.1)
plt.subplot(3,4,1)
plt.xticks(())
plt.ylim(0,1)
#plt.yticks(())
#开始画图
plt.title('b = 1.0')
plt.plot(fg['a'], fg['a1'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a2'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a3'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a4'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
#plt.ylabel('Probability of cooperator')


plt.subplot(3,4,2)
plt.ylim(0,1)
plt.xticks(())
plt.yticks(())
plt.title('b = 1.1')
plt.plot(fg['a'], fg['a5'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a6'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a7'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a8'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
#plt.ylabel('Probability of cooperator')


plt.subplot(3,4,3)
plt.ylim(0,1)
plt.xticks(())
plt.yticks(())
plt.title('b = 1.2')
plt.plot(fg['a'], fg['a9'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a10'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a11'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a12'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

plt.subplot(3,4,4)
plt.ylim(0,1)
plt.xticks(())
plt.yticks(())
plt.title('b = 1.3')
plt.plot(fg['a'], fg['a13'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a14'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a15'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a16'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

plt.subplot(3,4,5)
plt.ylim(0,1)
plt.xticks(())
#plt.yticks(())
plt.title('b = 1.4')
plt.plot(fg['a'], fg['a17'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a18'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a19'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a20'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
plt.ylabel('frequency of cooperator',fontsize = 10)

plt.subplot(3,4,6)
plt.ylim(0,1)
plt.xticks(())
plt.yticks(())
plt.title('b = 1.5')
plt.plot(fg['a'], fg['a21'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a22'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a23'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a24'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

plt.subplot(3,4,7)
plt.ylim(0,1)
plt.xticks(())
plt.yticks(())
plt.title('b = 1.6')
plt.plot(fg['a'], fg['a25'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a26'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a27'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a28'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

plt.subplot(3,4,8)
plt.ylim(0,1)
plt.xticks(())
plt.yticks(())
plt.title('b = 1.7')
plt.plot(fg['a'], fg['a29'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a30'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a31'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a32'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
#plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

plt.subplot(3,4,9)
plt.ylim(0,1)
#plt.xticks(())
#plt.yticks(())
plt.title('b = 1.8')
plt.plot(fg['a'], fg['a33'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a34'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a35'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a36'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

plt.subplot(3,4,10)
plt.ylim(0,1)
#plt.xticks(())
plt.yticks(())
plt.title('b = 1.9')
plt.plot(fg['a'], fg['a37'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a38'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a39'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a40'], color='#7DBFE8', label='非理性',linewidth = 0.8)
#plt.legend() # 显示图例
plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

plt.subplot(3,4,11)
plt.ylim(0,1)
#plt.xticks(())
plt.yticks(())
plt.title('b = 2.0')
plt.plot(fg['a'], fg['a41'], color='silver', label='imitation',linewidth = 0.8)
plt.plot(fg['a'], fg['a42'], color='#DF7A9F', label='memory & imitation',linewidth = 0.8)
plt.plot(fg['a'], fg['a43'], color='#76B994', label='attitude',linewidth = 0.8)
plt.plot(fg['a'], fg['a44'], color='#7DBFE8', label='attitude & memory & imitation',linewidth = 0.8)
plt.legend(bbox_to_anchor = (1,0.8),fontsize = 10) # 显示图例
plt.xlabel('times')
#plt.ylabel('Probability of cooperator')

#plt.subplot(3,4,12)
#plt.ylim(0,300)
#plt.xticks(())
#plt.yticks(())
#plt.title('number of game participants')
#plt.plot(fg['a'], fg['a34'], color='#DF7A9F', label='imitation',linewidth = 0.8)
#plt.legend(bbox_to_anchor = (1,0.8),fontsize = 10) # 显示图例
#plt.xlabel('times')

plt.savefig('E:/Desktop/20min.jpg')

# %%
plt.figure(figsize=(12,6))
plt.title('b = 2.0')
plt.plot(fg['a'], fg['a41'], color='silver', label='imitation',linewidth = 0.8)
plt.plot(fg['a'], fg['a42'], color='#DF7A9F', label='memory & imitation',linewidth = 0.8)
plt.plot(fg['a'], fg['a43'], color='#76B994', label='attitude',linewidth = 0.8)
plt.plot(fg['a'], fg['a44'], color='#7DBFE8', label='attitude & memory & imitation',linewidth = 0.8)
plt.legend(bbox_to_anchor = (1,0.8),fontsize = 10) # 显示图例
plt.xlabel('times')
plt.savefig('E:/Desktop/10min2.0.jpg')

# %%
plt.figure(figsize=(12,6))
plt.title('b = 1.0')
plt.plot(fg['a'], fg['a1'], color='silver', label='理性（不含历史）',linewidth = 0.8)
plt.plot(fg['a'], fg['a2'], color='#DF7A9F', label='理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a3'], color='#76B994', label='非理性',linewidth = 0.8)
plt.plot(fg['a'], fg['a4'], color='#7DBFE8', label='非理性',linewidth = 0.8)
