# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv('E:/Desktop/wxy/结果/data.csv',header = None)

# %%
filenames_out = ('E:/Desktop/wxy/结果/6历史+模仿\m=0.1',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.25',
                 'E:/Desktop/wxy/结果/6历史+模仿\m=0.1',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.5',
                 'E:/Desktop/wxy/结果/6历史+模仿\m=0.1',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.75',
                )

# %%
i = 1
for m in [2,8]:
    for j in range(len(filenames_out)):
        allDir = 'b = ' + str(m)
        fname2 = 'P_c.csv'
        dataa = pd.read_csv(os.path.join(filenames_out[j], allDir,fname2))
        data[i] = dataa['0']
        i = i + 1

# %%
linecolor = ('#1B5E20','#C83828')
plt.figure(figsize=(3,1.4),dpi=600)
plt.subplots_adjust(hspace=0.3, wspace=0.1)
font_size = 6
line_width = 0.6
plt.subplot(2,3,1)
plt.xticks(())
#plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[1], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[2], color=linecolor[1],linewidth = line_width)
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(30,0.66 ,' b = 1.2 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,2)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[3], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[4], color=linecolor[1],linewidth = line_width)
plt.text(30,0.66 ,' b = 1.2 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,3)

plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[5], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[6], color=linecolor[1],linewidth = line_width)
plt.text(30,0.66 ,' b = 1.2 \n'+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)
plt.subplot(2,3,4)
#plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[7], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[8], color=linecolor[1],linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(30,0.66 ,' b = 1.8 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)


plt.subplot(2,3,5)

#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[9], color=linecolor[0],label = chr(946)+'$_i$ = 0',linewidth = line_width)
plt.plot(data[0],data[10], color=linecolor[1],label = chr(946)+'$_i$ = f$_{i}$$^{c}$',linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.legend(ncol=3, bbox_to_anchor = (1.40,1.42),
           prop = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
          frameon = False) # 显示图例
plt.text(30,0.66 ,' b = 1.8 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,6)
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[11], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[12], color=linecolor[1],linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(30,0.66 ,' b = 1.8 \n '+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)          

plt.savefig('E:/Desktop/epl/epl论文格式模板/epl2/figure5.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure6.svg',bbox_inches='tight',pad_inches=0.0)

# %%
linecolor = ('#1B5E20','#C83828')
plt.figure(figsize=(5,1),dpi=600)
plt.subplots_adjust(hspace=0.6, wspace=0.5)
font_size = 6
line_width = 0.6
plt.subplot(1,3,1)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[1], color=linecolor[0],linewidth = line_width,label = chr(946)+'$_i$ = 0')
plt.plot(data[0],data[2], color=linecolor[1],linewidth = line_width,label = chr(946)+'$_i$ = f$_{i}$$^{c}$')
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.legend(ncol=1, 
           prop = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
          frameon = False) # 显示图例
plt.title('(a)'+  chr(956)+' = 0.25',y=-0.5,
         fontdict = {'family' : 'Times New Roman','size': font_size,},
         )
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)


plt.subplot(1,3,2)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[3], color=linecolor[0],linewidth = line_width,label = chr(946)+'$_i$ = 0')
plt.plot(data[0],data[4], color=linecolor[1],linewidth = line_width,label = chr(946)+'$_i$ = f$_{i}$$^{c}$')
plt.legend(ncol=1, 
           prop = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
          frameon = False) # 显示图例
plt.title('(b)'+  chr(956)+' = 0.50',y=-0.5,
         fontdict = {'family' : 'Times New Roman','size': font_size,},
         )
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.subplot(1,3,3)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[5], color=linecolor[0],linewidth = line_width,label = chr(946)+'$_i$ = 0')
plt.plot(data[0],data[6], color=linecolor[1],linewidth = line_width,label = chr(946)+'$_i$ = f$_{i}$$^{c}$')
plt.legend(ncol=1,
           prop = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
          frameon = False) # 显示图例
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.title('(c) '+ chr(956)+' = 0.75',y=-0.5,
         fontdict = {'family' : 'Times New Roman','size': font_size,},
         )
plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)


plt.savefig('E:/Desktop/7.29/figure7.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure7_改.svg',bbox_inches='tight',pad_inches=0.0)

# %%
linecolor = ('#1B5E20','#C83828')
plt.figure(figsize=(3,2),dpi=600)
plt.subplots_adjust(hspace=0.6, wspace=0.5)
linecolor = ('black','#1B5E20','#4d5aaf','#C83828')
font_size = 7
line_width = 0.6
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[1], color=linecolor[0],linewidth = line_width,label = chr(946)+'$_i$ = 0')
plt.plot(data[0],data[2], color=linecolor[1],linewidth = line_width,label = chr(946)+'$_i$ = f$_{c}$$^{i}$, '+ chr(956)+' = 0.25')
plt.plot(data[0],data[4], color=linecolor[2],linewidth = line_width,label = chr(946)+'$_i$ = f$_{c}$$^{i}$, '+ chr(956)+' = 0.50')
plt.plot(data[0],data[6], color=linecolor[3],linewidth = line_width,label = chr(946)+'$_i$ = f$_{c}$$^{i}$, '+ chr(956)+' = 0.75')
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.legend(ncol=2, 
           prop = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
          frameon = False) # 显示图例

plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)



plt.savefig('E:/Desktop/7.29/figure8.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure8_改.svg',bbox_inches='tight',pad_inches=0.0)
