# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import random
import os
import openpyxl

# %%
data = pd.read_csv('E:/Desktop/wxy/结果/data1.csv',header = None)

# %%
###wi选取
#filenames_out = ('E:/Desktop/wxy/结果/2wi选取/1收益最大/30min','E:/Desktop/wxy/结果/2wi选取/2离差最小/30min','E:/Desktop/wxy/结果/2wi选取/3随机/30min')
####lambda
filenames_out = ('E:/Desktop/wxy/结果/5模仿收益最大/5a个人/0.25',
                 'E:/Desktop/wxy/结果/5随机模仿/0.25',
                 'E:/Desktop/wxy/结果/5模仿收益最大/5a个人/0.5',
                 'E:/Desktop/wxy/结果/5随机模仿/0.5',
                 'E:/Desktop/wxy/结果/5模仿收益最大/5a个人/0.75',
                 'E:/Desktop/wxy/结果/5随机模仿/0.75')
##情绪分布
#filenames_out = ('E:/Desktop/wxy/结果/5a个人/0.25','E:/Desktop/wxy/结果/5a个人/0.5','E:/Desktop/wxy/结果/5a个人/0.75')

# %%
i = 1 
for m in range(0,11,2):
    allDir = 'b = ' + str(m)
    fname2 = 'P_c.csv'
    dataa = pd.read_csv(os.path.join(filenames_out[0], allDir,fname2))
    data[i] = dataa['0']
    i = i + 6
j = 2 
for mm in range(0,11,2):
    allDir = 'b = ' + str(mm)
    fname2 = 'P_c.csv'
    dataa = pd.read_csv(os.path.join(filenames_out[1], allDir,fname2))
    data[j] = dataa['0']
    j = j + 6
k = 3
for mmm in range(0,11,2):
    allDir = 'b = ' + str(mmm)
    fname2 = 'P_c.csv'
    dataa = pd.read_csv(os.path.join(filenames_out[2], allDir,fname2))
    data[k] = dataa['0']
    k = k + 6
r = 4
for mmmm in range(0,11,2):
    allDir = 'b = ' + str(mmmm)
    fname2 = 'P_c.csv'
    dataa = pd.read_csv(os.path.join(filenames_out[3], allDir,fname2))
    data[r] = dataa['0']
    r = r + 6
u = 5
for mmmmm in range(0,11,2):
    allDir = 'b = ' + str(mmmmm)
    fname2 = 'P_c.csv'
    dataa = pd.read_csv(os.path.join(filenames_out[4], allDir,fname2))
    data[u] = dataa['0']
    u = u + 6
o = 6
for mmmmmm in range(0,11,2):
    allDir = 'b = ' + str(mmmmmm)
    fname2 = 'P_c.csv'
    dataa = pd.read_csv(os.path.join(filenames_out[5], allDir,fname2))
    data[o] = dataa['0']
    o = o + 6

# %%
linecolor = ('#d67274','#b1c769','#ff2468','#0f7601','#C83828','#005b63')
plt.figure(figsize=(12,6))
plt.subplots_adjust(hspace=0.5, wspace=0.1)
plt.subplot(2,3,1)
plt.title('b = 1.0')
plt.xticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[1], color=linecolor[0],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[0] )
plt.plot(data[0],data[2], color=linecolor[1],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[1])
plt.plot(data[0],data[3], color=linecolor[2],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[2])
plt.plot(data[0],data[4], color=linecolor[3],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[3])
plt.plot(data[0],data[5], color=linecolor[4],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[4])
plt.plot(data[0],data[6], color=linecolor[5],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[5])

plt.ylabel('frequency of cooperator')


plt.subplot(2,3,2)
plt.title('b = 1.2')
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
q =1
plt.plot(data[0],data[1+6*q], color=linecolor[0],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[0] )
plt.plot(data[0],data[2+6*q], color=linecolor[1],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[1])
plt.plot(data[0],data[3+6*q], color=linecolor[2],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[2])
plt.plot(data[0],data[4+6*q], color=linecolor[3],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[3])
plt.plot(data[0],data[5+6*q], color=linecolor[4],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[4])
plt.plot(data[0],data[6+6*q], color=linecolor[5],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[0])

plt.subplot(2,3,3)
plt.title('b = 1.4')
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
q =2
plt.plot(data[0],data[1+6*q], color=linecolor[0],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[0] )
plt.plot(data[0],data[2+6*q], color=linecolor[1],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[1])
plt.plot(data[0],data[3+6*q], color=linecolor[2],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[2])
plt.plot(data[0],data[4+6*q], color=linecolor[3],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[3])
plt.plot(data[0],data[5+6*q], color=linecolor[4],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[4])
plt.plot(data[0],data[6+6*q], color=linecolor[5],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[5])

plt.subplot(2,3,4)
plt.title('b = 1.6')
#plt.xticks(())
#plt.yticks(())
plt.ylim(-0.1,1.1)
q =3
plt.plot(data[0],data[1+6*q], color=linecolor[0],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[0] )
plt.plot(data[0],data[2+6*q], color=linecolor[1],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[1])
plt.plot(data[0],data[3+6*q], color=linecolor[2],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[2])
plt.plot(data[0],data[4+6*q], color=linecolor[3],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[3])
plt.plot(data[0],data[5+6*q], color=linecolor[4],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[4])
plt.plot(data[0],data[6+6*q], color=linecolor[5],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[5])
plt.ylabel('frequency of cooperator')
plt.xlabel('t')

plt.subplot(2,3,5)
plt.title('b = 1.8')
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
q =4
plt.plot(data[0],data[1+6*q], color=linecolor[0],label = 'minimum variance & mu = 0.25',linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[0] )
plt.plot(data[0],data[2+6*q], color=linecolor[1],label = 'random & mu = 0.25',linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[1])
plt.plot(data[0],data[3+6*q], color=linecolor[2],label = 'minimum variance & mu = 0.50',linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[2])
plt.plot(data[0],data[4+6*q], color=linecolor[3],label = 'random & mu = 0.50',linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[3])
plt.plot(data[0],data[5+6*q], color=linecolor[4],label = 'minimum variance & mu = 0.75',linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[4])
plt.plot(data[0],data[6+6*q], color=linecolor[5],label = 'random & mu = 0.75',linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[5])
plt.legend(ncol=3, bbox_to_anchor = (1.95,1.45))
plt.xlabel('t')

plt.subplot(2,3,6)
plt.title('b = 2.0')
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
q =5
plt.plot(data[0],data[1+6*q], color=linecolor[0],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[0] )
plt.plot(data[0],data[2+6*q], color=linecolor[1],linewidth = 1,linestyle = '-',marker = 's',markersize = 3,markeredgecolor = linecolor[1])
plt.plot(data[0],data[3+6*q], color=linecolor[2],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[2])
plt.plot(data[0],data[4+6*q], color=linecolor[3],linewidth = 1,linestyle = '-',marker = 'p',markersize = 3,markeredgecolor = linecolor[3])
plt.plot(data[0],data[5+6*q], color=linecolor[4],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[4])
plt.plot(data[0],data[6+6*q], color=linecolor[5],linewidth = 1,linestyle = '-',marker = 'x',markersize = 5,markeredgecolor = linecolor[5])

plt.xlabel('t')

plt.savefig('E:/Desktop/wxy/结果/5总对比.svg')
