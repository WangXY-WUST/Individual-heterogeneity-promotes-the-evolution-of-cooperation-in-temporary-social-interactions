# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

data = pd.read_csv('E:/Desktop/wxy/结果/data1.csv',header = None)

# %%
#总的
filenames_out = ('E:/Desktop/wxy/结果/7情绪+历史/mu=0.25',
                 'E:/Desktop/wxy/结果/5随机模仿/m=0.1mu=0.25',
                 'E:/Desktop/wxy/结果/5模仿收益最大/m=0.1mu=0.25',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.25',
                 'E:/Desktop/wxy/结果/7情绪+历史/mu=0.5',
                 'E:/Desktop/wxy/结果/5随机模仿/m=0.1mu=0.5',
                 'E:/Desktop/wxy/结果/5模仿收益最大/m=0.1mu=0.5',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.5',
                 'E:/Desktop/wxy/结果/7情绪+历史/mu=0.75', 
                 'E:/Desktop/wxy/结果/5随机模仿/m=0.1mu=0.75',
                 'E:/Desktop/wxy/结果/5模仿收益最大/m=0.1mu=0.75',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.75',
                )

# %%
i = 1
for m in [2,8]:
    for j in range(len(filenames_out)):
        allDir = 'b = ' + str(m)
        fname2 = 'P_c.csv'
        dataa = pd.read_csv(os.path.join(filenames_out[j], allDir,fname2))
        data[i] = dataa['0']
        i = i + 1

# %%
#总的
filenames_out = (
                 'E:/Desktop/wxy/结果/7情绪+历史/mu=0.5/b = 2/P_c.csv',
                 'E:/Desktop/wxy/结果/8情绪+模仿/b = 2/P_c.csv',
                 'E:/Desktop/wxy/结果/5模仿方差最小/m=0.1mu=0.5/b = 2/P_c.csv',
                )
i = 1
for j in range(len(filenames_out)):
    dataa = pd.read_csv(filenames_out[j])
    data[i] = dataa['0']
    i = i + 1 



# -*- coding: utf-8 -*-
#linecolor = ('black','#1B5E20','#8C63C4','#C83828')
linecolor = ('#1B5E20','black','#4d5aaf','#C83828')
#linecolor = ('#984ea3','#377eb8','#4daf4a','#C83828')
font_size = 4
line_width = 0.6
ts = 4
plt.figure(figsize=(6,2),dpi=600)

plt.subplot(2,3,2)
#plt.title( chr(956)+' = 0.50',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[2], color=linecolor[2],linewidth = line_width,label = chr(955)+'(m,n$_i$) = 0')
plt.plot(data[0],data[1], color=linecolor[0],linewidth = line_width,label = chr(955)+'(m,n$_i$) = 1')
plt.plot(data[0],data[3], color=linecolor[3],linewidth = line_width,label = '0 ≤ '+chr(955)+'(m,n$_i$)'+' < 1')

plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.legend(ncol=1,bbox_to_anchor = (0.58,0.58),
           prop = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
          frameon = False) # 显示图例
#loc = 'upper left'



plt.savefig('E:/Desktop/7.29/figure7.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure7_改.svg',bbox_inches='tight',pad_inches=0.0)

# %%
#linecolor = ('black','#1B5E20','#8C63C4','#C83828')
linecolor = ('#C83828','black','#4d5aaf','#1B5E20')
#linecolor = ('#984ea3','#377eb8','#4daf4a','#C83828')
plt.figure(figsize=(3,1.4),dpi=600)
plt.subplots_adjust(hspace=0.6, wspace=0.1)
font_size = 5
line_width = 0.6
ts = 4

plt.subplot(2,3,1)
plt.text(32,0.66 ,' b = 1.2 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.xticks(())
#plt.yticks(())
plt.ylim(-0.1,1.1)
#plt.text(45,0.8,' b = 1.2 ',fontname = 'Times New Roman',size = 20)
plt.plot(data[0],data[1], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[2], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[3], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[4], color=linecolor[3],linewidth = line_width)

#loc = 'upper left'
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
#plt.text(-27,0.5,' b = 1.2 ',fontname = 'Times New Roman',size = 20)
plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,2)
#plt.title( chr(956)+' = 0.50',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[5], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[6], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[7], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[8], color=linecolor[3],linewidth = line_width)
plt.text(32,0.66 ,' b = 1.2 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)



plt.subplot(2,3,3)
#plt.title( chr(956)+' = 0.75',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[9], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[10], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[11], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[12], color=linecolor[3],linewidth = line_width)
plt.text(32,0 ,' b = 1.2 \n'+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)


plt.subplot(2,3,4)
#plt.title('b = 1.6',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
#plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[13], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[14], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[15], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[16], color=linecolor[3],linewidth = line_width)
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
#plt.text(-27,0.5,' b = 1.8 ',fontname = 'Times New Roman',size = 20)
plt.text(32,0.66 ,' b = 1.8 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)



plt.subplot(2,3,5)
#plt.title('b = 1.8',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
a = chr(945)
u = chr(956)
plt.plot(data[0],data[17], color=linecolor[0],label = 'Remove imitation ',linewidth = line_width)
plt.plot(data[0],data[18], color=linecolor[1],label = 'Random ',linewidth = line_width)
plt.plot(data[0],data[19], color=linecolor[2],label = 'Maximum payoff ',linewidth = line_width)
plt.plot(data[0],data[20], color=linecolor[3],label = 'Minimun deviation' ,linewidth = line_width)

plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.legend(ncol=2, bbox_to_anchor = (1.8,1.62),
           prop = {'family' : 'Times New Roman','size': font_size},
          frameon = False) # 显示图例
#loc = 'upper left'
plt.text(32,0.66 ,' b = 1.8 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,6)
#plt.title('b = 2.0',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[21], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[22], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[23], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[24], color=linecolor[3],linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(32,0 ,' b = 1.8 \n'+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.savefig('E:/Desktop/epl/epl论文格式模板/epl2/figure8.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure9.svg',bbox_inches='tight',pad_inches=0.0)

# %%
filenames_out = (
                 'E:/Desktop/wxy/结果/0探究m/m=10mu=0.5',
                 'E:/Desktop/wxy/结果/0探究m/m=0.01mu=0.5',
                 'E:/Desktop/wxy/结果/0探究m/m=0.1mu=0.5',
                 'E:/Desktop/wxy/结果/0探究m/m=1mu=0.5',

                )
i = 1
for m in [8]:
    for j in range(len(filenames_out)):
        allDir = 'b = ' + str(m)
        fname2 = 'P_c.csv'
        dataa = pd.read_csv(os.path.join(filenames_out[j], allDir,fname2))
        data[i] = dataa['0']
        i = i + 1

# %%
#linecolor = ('black','#1B5E20','#8C63C4','#C83828')
linecolor = ('black','#4d5aaf','#C83828','#1B5E20')
#linecolor = ('#984ea3','#377eb8','#4daf4a','#C83828')
plt.figure(figsize=(3,2),dpi=600)
plt.subplots_adjust(hspace=0.6, wspace=0.1)
font_size = 7
line_width = 0.6
ts = 4

#plt.title( chr(956)+' = 0.50',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)


plt.plot(data[0],data[2], color=linecolor[1],label = 'm = 0.01',linewidth = line_width)
plt.plot(data[0],data[3], color=linecolor[2],label = 'm = 0.10',linewidth = line_width)
plt.plot(data[0],data[4], color=linecolor[3],label = 'm = 1.00' ,linewidth = line_width)
plt.plot(data[0],data[1], color=linecolor[0],label = 'm = 10.00',linewidth = line_width)
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.legend(ncol=2,
           prop = {'family' : 'Times New Roman','size': font_size},
          frameon = False) # 显示图例

plt.yticks((0,0.25,0.5,0.75,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.savefig('E:/Desktop/7.29/figure6.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure6_改.svg',bbox_inches='tight',pad_inches=0.0)

# %%
#linecolor = ('black','#1B5E20','#8C63C4','#C83828')
linecolor = ('#C83828','black','#4d5aaf','#1B5E20')
#linecolor = ('#984ea3','#377eb8','#4daf4a','#C83828')
plt.figure(figsize=(3,1.4),dpi=600)
plt.subplots_adjust(hspace=0.6, wspace=0.1)
font_size = 5
line_width = 0.6
ts = 4

plt.subplot(2,3,1)
plt.text(32,0.66 ,' b = 1.2 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.xticks(())
#plt.yticks(())
plt.ylim(-0.1,1.1)
#plt.text(45,0.8,' b = 1.2 ',fontname = 'Times New Roman',size = 20)
plt.plot(data[0],data[1], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[2], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[3], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[4], color=linecolor[3],linewidth = line_width)

#loc = 'upper left'
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
#plt.text(-27,0.5,' b = 1.2 ',fontname = 'Times New Roman',size = 20)
plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,2)
#plt.title( chr(956)+' = 0.50',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[5], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[6], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[7], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[8], color=linecolor[3],linewidth = line_width)
plt.text(32,0.66  ,' b = 1.2 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)



plt.subplot(2,3,3)
#plt.title( chr(956)+' = 0.75',fontname = 'Times New Roman',fontsize = 20,pad = 20)
plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[9], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[10], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[11], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[12], color=linecolor[3],linewidth = line_width)
plt.text(32,-0.05  ,' b = 1.2 \n'+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks(fontproperties='Times New Roman', size=font_size)


plt.subplot(2,3,4)
#plt.title('b = 1.6',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
#plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[13], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[14], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[15], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[16], color=linecolor[3],linewidth = line_width)
plt.ylabel('f$_c$',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
#plt.text(-27,0.5,' b = 1.8 ',fontname = 'Times New Roman',size = 20)
plt.text(32,0.66  ,' b = 1.8 \n'+ chr(956)+' = 0.25',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks((0,0.5,1),fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)



plt.subplot(2,3,5)
#plt.title('b = 1.8',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
a = chr(945)
u = chr(956)
plt.plot(data[0],data[17], color=linecolor[0],label = 'Updating rule(ii)',linewidth = line_width)
plt.plot(data[0],data[18], color=linecolor[1],label = 'Updating rule(iii), m = 0.01',linewidth = line_width)
plt.plot(data[0],data[19], color=linecolor[2],label = 'Updating rule(iii), m = 0.1',linewidth = line_width)
plt.plot(data[0],data[20], color=linecolor[3],label = 'Updating rule(iii), m = 1' ,linewidth = line_width)

plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.legend(ncol=2, bbox_to_anchor = (1.9,1.66),
           prop = {'family' : 'Times New Roman','size': font_size},
          frameon = False) # 显示图例
#loc = 'upper left'
plt.text(32,0.66  ,' b = 1.8 \n'+ chr(956)+' = 0.50',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.subplot(2,3,6)
#plt.title('b = 2.0',fontname = 'Times New Roman',fontsize = 15)
#plt.xticks(())
plt.yticks(())
plt.ylim(-0.1,1.1)
plt.plot(data[0],data[21], color=linecolor[0],linewidth = line_width)
plt.plot(data[0],data[22], color=linecolor[1],linewidth = line_width)
plt.plot(data[0],data[23], color=linecolor[2],linewidth = line_width)
plt.plot(data[0],data[24], color=linecolor[3],linewidth = line_width)
plt.xlabel('t',fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'})
plt.text(32,-0.05  ,' b = 1.8 \n'+ chr(956)+' = 0.75',
         fontdict = {'family' : 'Times New Roman','size': font_size,'style':'oblique'},
         )
plt.yticks(fontproperties='Times New Roman', size=font_size)#设置大小及加粗
plt.xticks((0,10,20,30,40,50),fontproperties='Times New Roman', size=font_size)

plt.savefig('E:/Desktop/epl/epl论文格式模板/epl2/figure6.eps',bbox_inches='tight',pad_inches=0.0)
plt.savefig('E:/Desktop/wxy/论文图/figure7.svg',bbox_inches='tight',pad_inches=0.0)
